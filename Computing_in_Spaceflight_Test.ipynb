# %% [markdown]
# <a href="https://colab.research.google.com/github/cse10001/cse10001.github.io/blob/main/Computing_in_Spaceflight_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cbidinot/mentium_nd.git
# Out:
# Cloning into 'mentium_nd'...
# remote: Enumerating objects: 226, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 226 (delta 50), reused 9 (delta 7), pack-reused 143 (from 1)
# Receiving objects: 100% (226/226), 394.18 KiB | 1.67 MiB/s, done.
# Resolving deltas: 100% (122/122), done.

# %%
# %cd /content/mentium_nd/
# !git fetch origin main
# Out:
# /content/mentium_nd
# From https://github.com/cbidinot/mentium_nd
#  * branch            main       -> FETCH_HEAD

# %%
# !git pull origin main
# !git checkout main -f
# Out:
# From https://github.com/cbidinot/mentium_nd
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
# !chmod +x /content/mentium_nd/main.py
# !/content/mentium_nd/main.py -c /content/mentium_nd/defaultcfg.json
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/xusaiai/cifar-10-pythontargz
# License(s): unknown
# ...
# 100% 162M/162M [00:01<00:00, 116MB/s]
#
# Extraction complete. Check the './data' folder.
# Using GPU: Tesla T4
# Starting training...
# Evaluating: 100% 313/313 [00:02<00:00, 107.45it/s]
# Predicted Class ID: 3
# Actual Class ID: 3
# <IPython.core.display.Image object>
# Predicted Class ID: 6
# Actual Class ID: 6
# <IPython.core.display.Image object>
# Finished training, now running with TMR...
# TMR Accuracy: 0.5362
# Original Test Loss: 1.2826, Original Accuracy: 0.5385
# TMR vs Original Diff: 0.0370, TMR Fails (No Consensus): 0.0019
